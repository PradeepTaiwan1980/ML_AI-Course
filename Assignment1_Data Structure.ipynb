# %% [markdown]
# # Problem Statement
# ![Problem%20Statement.jpg](attachment:Problem%20Statement.jpg)

# %%
nbconvert[webpdf]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-388-9fade26a2e96> in <module>
# ----> 1 nbconvert[webpdf]
#
# NameError: name 'nbconvert' is not defined

# %%
student_marks = [['Name', ['A','B','C','D','E','F']],
                 ['Ankit',   [41, 34, 45, 55, 63]],  
                 ['Aravind', [42, 23, 34, 44, 53]],
                 ['Lakshay', [32, 23, 13, 54, 67]],  
                 ['Gyan', [23, 82, 23, 63, 34]],
                 ['Pranav', [21, 23, 25, 56, 56]],       
                ]

# %%
student_marks
# Out:
# [['Name', ['A', 'B', 'C', 'D', 'E', 'F']],
#  ['Ankit', [41, 34, 45, 55, 63]],
#  ['Aravind', [42, 23, 34, 44, 53]],
#  ['Lakshay', [32, 23, 13, 54, 67]],
#  ['Gyan', [23, 82, 23, 63, 34]],
#  ['Pranav', [21, 23, 25, 56, 56]]]

# %% [markdown]
# ## Who scored the highest marks in the subject B 🏆 ?

# %%
for student in student_marks[1:]:
    name = student[0]
    marks_in_B = student[1][1]
    
    print(name, marks_in_B)
# Out:
# Ankit 34
# Aravind 23
# Lakshay 23
# Gyan 82
# Pranav 23

# %%
# list to store the marks
student_with_marks_in_B = []

for student in student_marks[1:]:
    name = student[0]
    marks_in_B = student[1][1]
    
    student_with_marks_in_B.append([marks_in_B,name])

# %%
student_with_marks_in_B
# Out:
# [[34, 'Ankit'], [23, 'Aravind'], [23, 'Lakshay'], [82, 'Gyan'], [23, 'Pranav']]

# %%
sorted(student_with_marks_in_B)
# Out:
# [[23, 'Aravind'], [23, 'Lakshay'], [23, 'Pranav'], [34, 'Ankit'], [82, 'Gyan']]

# %%
sorted(student_with_marks_in_B)[-1][1]
# Out:
# 'Gyan'

# %% [markdown]
# ## What is average scored subject C?

# %%
# list to store the marks
student_marks
# Out:
# [['Name', ['A', 'B', 'C', 'D', 'E', 'F']],
#  ['Ankit', [41, 34, 45, 55, 63]],
#  ['Aravind', [42, 23, 34, 44, 53]],
#  ['Lakshay', [32, 23, 13, 54, 67]],
#  ['Gyan', [23, 82, 23, 63, 34]],
#  ['Pranav', [21, 23, 25, 56, 56]]]

# %%
# list to store the marks
student_with_marks_in_C = []

for student1 in student_marks[1:]:
    name1 = student1[0]
    marks_in_C = student1[1][2]
    
    student_with_marks_in_C.append([marks_in_C,name1])

# %%
student_with_marks_in_C
# Out:
# [[45, 'Ankit'], [34, 'Aravind'], [13, 'Lakshay'], [23, 'Gyan'], [25, 'Pranav']]

# %%
sorted(student_with_marks_in_C)
# Out:
# [[13, 'Lakshay'], [23, 'Gyan'], [25, 'Pranav'], [34, 'Aravind'], [45, 'Ankit']]

# %%
Total = sorted(student_with_marks_in_C)[0][0] + sorted(student_with_marks_in_C)[1][0] + sorted(student_with_marks_in_C)[2][0] + sorted(student_with_marks_in_C)[3][0] + sorted(student_with_marks_in_C)[4][0]

# %%
Total
# Out:
# 140

# %%
number = 0
Total = 0
while (number < 5):
    Total = Total + sorted(student_with_marks_in_C)[number][0]
    number = number + 1

# %%
Total
# Out:
# 140

# %%
Average = Total/5
print (Average)
# Out:
# 28.0

# %% [markdown]
# ## Who scored highest percentage of marks?

# %%
student_marks
# Out:
# [['Name', ['A', 'B', 'C', 'D', 'E', 'F']],
#  ['Ankit', [41, 34, 45, 55, 63]],
#  ['Aravind', [42, 23, 34, 44, 53]],
#  ['Lakshay', [32, 23, 13, 54, 67]],
#  ['Gyan', [23, 82, 23, 63, 34]],
#  ['Pranav', [21, 23, 25, 56, 56]]]

# %%
initial = []
number = 0
while (number < 6):
    number = number + 1
student_marks[1:number]
# Out:
# [['Ankit', [41, 34, 45, 55, 63]],
#  ['Aravind', [42, 23, 34, 44, 53]],
#  ['Lakshay', [32, 23, 13, 54, 67]],
#  ['Gyan', [23, 82, 23, 63, 34]],
#  ['Pranav', [21, 23, 25, 56, 56]]]

# %%
student_total = []
for student_mark in student_marks[1:]:
    print(student_mark)
    sum_marks = sum(student_mark[1])
    name = student_mark[0]
    student_total.append((name,sum_marks))
student_total
# Out:
# ['Ankit', [41, 34, 45, 55, 63]]
# ['Aravind', [42, 23, 34, 44, 53]]
# ['Lakshay', [32, 23, 13, 54, 67]]
# ['Gyan', [23, 82, 23, 63, 34]]
# ['Pranav', [21, 23, 25, 56, 56]]
# [('Ankit', 238),
#  ('Aravind', 196),
#  ('Lakshay', 189),
#  ('Gyan', 225),
#  ('Pranav', 181)]

# %%
student_total.sort(key = lambda x:x[1])

# %%
student_total.reverse()

# %%
print(student_total)
print("Highest Marks Student=", student_total[0])
# Out:
# [('Ankit', 238), ('Gyan', 225), ('Aravind', 196), ('Lakshay', 189), ('Pranav', 181)]
# Highest Marks Student= ('Ankit', 238)

# %% [markdown]
# ## Who scored highest percentage of marks in Top 4 Subjects?

# %%
student_marks = [['Name', ['A','B','C','D','E']],
                 ['Ankit',   [41, 34, 45, 55, 63]],  
                 ['Aravind', [42, 23, 34, 44, 53]],
                 ['Lakshay', [32, 23, 13, 54, 67]],  
                 ['Gyan', [23, 82, 23, 63, 34]],
                 ['Pranav', [21, 23, 25, 56, 56]],       
                ]

# %%
student_marks
# Out:
# [['Name', ['A', 'B', 'C', 'D', 'E']],
#  ['Ankit', [41, 34, 45, 55, 63]],
#  ['Aravind', [42, 23, 34, 44, 53]],
#  ['Lakshay', [32, 23, 13, 54, 67]],
#  ['Gyan', [23, 82, 23, 63, 34]],
#  ['Pranav', [21, 23, 25, 56, 56]]]

# %%
student_marks[1][1]
min_numberAnkit = min(student_marks[1][1])
min_numberAnkit
# Out:
# 34

# %%
student_marks[2][1]
min_numberAravind = min(student_marks[2][1])
min_numberAravind
# Out:
# 23

# %%
student_marks[3][1]
min_numberLakshay = min(student_marks[3][1])
min_numberLakshay
# Out:
# 13

# %%
student_marks[4][1]
min_numberGyan = min(student_marks[4][1])
min_numberGyan
# Out:
# 23

# %%
student_marks[5][1]
min_numberPranav = min(student_marks[5][1])
min_numberPranav
# Out:
# 21

# %%
student_total = []
for student_mark in student_marks[1:]:
    sum_marks = sum(student_mark[1])
    number = 1
#    for number in range(5):
#       if number < 5:
#           continue   
    sum_marks = sum_marks - min(student_marks[number][1])
    name = student_mark[0]
    student_total.append((name,sum_marks))
student_total
# Out:
# [('Ankit', 204),
#  ('Aravind', 162),
#  ('Lakshay', 155),
#  ('Gyan', 191),
#  ('Pranav', 147)]

# %%
[('Ankit', 238),
 ('Aravind', 196),
 ('Lakshay', 189),
 ('Gyan', 225),
 ('Pranav', 181)]

# %%
student_total[1]
# Out:
# ('Aravind', 196)

# %%
Ankit1 = 41+45+55+63
Ankit1
# Out:
# 204

# %%
Aravind2 = 42+34+44+53
Aravind2
# Out:
# 173

# %%
Lakshay2 = 32+23+54+67
Lakshay2
# Out:
# 176

# %%
Gyan2 = 82+23+63+34
Gyan2
# Out:
# 202

# %%
Pranav2 = 21+23+25+56
Pranav2
# Out:
# 125

# %%
Marks2 = [Ankit1, Aravind2, Lakshay2, Gyan2, Pranav2]
Marks2.sort()
Marks2
# Out:
# [125, 173, 176, 202, 204]

# %%
print("Highest Marks Student (Ankit) = :", Marks2[-1])
# Out:
# Highest Marks Student (Ankit) = : 204
